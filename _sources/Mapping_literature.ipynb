# %% [markdown]
# # Mapping literature

# %%
import stanza
import requests
import folium

nlp = stanza.Pipeline(lang='en', processors='tokenize,ner')
# Out:
# 2024-04-18 02:25:21 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | ner       | ontonotes |
# =========================
#
# 2024-04-18 02:25:21 INFO: Use device: cpu
# 2024-04-18 02:25:21 INFO: Loading: tokenize
# 2024-04-18 02:25:21 INFO: Loading: ner
# 2024-04-18 02:25:22 INFO: Done loading processors!

# %%
def find_locations(file):
    novel = open(file,encoding='utf-8')
    locations = []

    for paragraph in novel:
        doc = nlp(paragraph)

        for sent in doc.sentences: 
            location = ''
            for token in sent.tokens:
                if token.ner == 'S-LOC':
                    locations.append(token.text)
                elif token.ner == 'B-LOC':
                    location = token.text + ' '
                elif token.ner == 'I-LOC':
                    location += token.text + ' '
                elif token.ner == 'E-LOC':
                    location += token.text
                    locations.append(location.strip())

                if token.ner == 'S-GPE':
                    locations.append(token.text)
                elif token.ner == 'B-GPE':
                    location = token.text + ' '
                elif token.ner == 'I-GPE':
                    location += token.text + ' '
                elif token.ner == 'E-GPE':
                    location += token.text 
                    locations.append(location.strip())

    return list(set(locations))

# %%
locations = find_locations('passage_to_india.txt')

# %%
data = []

for a in locations:

    url = f'https://nominatim.openstreetmap.org/search?q={a}&format=json'

    response = requests.get( url ) # The spaces in each address are automatically encoded as '%20' by requests
    json_data = response.json()
    # json_data is a list of results; we assume that the first result is always correct(!)
    if len(json_data)>0:
        latitude = json_data[0]['lat']
        longitude = json_data[0]['lon']
        data.append( [latitude,longitude,a] )
# Out:
# Mau—elephants
# Himalayas
# Hampi
# Oxford
# Tukaram
# Deora
# Hindustan
# Mussoorie
# Frome
# Shalimar
# Kashmir
# Karachi
# England
# Ganges
# Allahabad
# Alexandria
# Dravidia
# Lahore
# Suez
# Himalayan India
# Cheltenham
# Belgium
# Sipra
# the Kawa Dol
# Guatemala
# Boum
# Hamidullah’s
# Anglo - India
# the Marabar Hills
# Plains
# East Africa
# Marabar
# District
# Mohammedan
# the Province
# the Indian Ocean
# Eastbourne
# Walhalla
# Dilkusha
# Upper India
# Central India
# Gangavati
# Great Britain
# Persia
# Elephanta
# Bahadur
# Paris
# the Hills
# Mau
# Tukaram .
# the City Magistrate
# Rajah
# Ringnod
# Khajraha
# Bethlehem
# Agra
# East
# Crete
# Punjab
# Girnar
# Jehovah
# Bengal
# the Bottomless Pit
# Turkestan
# Chandrapore city
# Bosphorus
# Levant
# Tunbridge Wells
# London_
# Chandrapore
# Japan
# Maidan
# Florence
# Mecca
# Mudkul
# the English Lakes
# Bombay
# INDIA
# Northamptonshire
# Egypt
# St. Mark
# Babur’s
# Hyderabad
# Arabia
# Nureddin
# Mediterranean
# Benares
# Providence
# Europe
# Bijapur
# the Nawab Bahadur
# Calcutta
# the British Empire
# Asia
# West
# Nazareth
# Ujjain
# Kabul
# Venice
# Esmiss Esmoor
# Thibet
# Maharani
# India
# Hampstead
# Simla
# Aden
# Lucknow
# Orientals
# Herat
# Hamidullah
# Cambridge
# U.S.A
# Hindu States
# Native States
# Bhopal
# LONDON
# London
# Cordova
# Native State
# North
# the Native States
# Afghanistan
# Africa
# Paradise
# Marabar Hills
# Mohurram
# Colaba
# a Marabar cave
# Gokul
# Delhi
# the Marabar Caves
# Peshawar
# the Red Sea
# Kerbela
# Mandu
# San Giorgio
# Rajputana
# Ferghana
# Asirgarh
# TEMPLE

# %%
map = folium.Map(location=[25.36613847824339, 78.41184545925708],
tiles = 'OpenStreetMap' ,
    zoom_start=4)

for point in data:
    folium.Marker([point[0],point[1]],
        popup = point[2] ).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cc8baf50a98ff89eb7e5e45507af612 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cc8baf50a98ff89eb7e5e45507af612&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cc8baf50a98ff89eb7e5e45507af612 = L.map(
#                 &quot;map_8cc8baf50a98ff89eb7e5e45507af612&quot;,
#                 {
#                     center: [25.36613847824339, 78.41184545925708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72ebf1082d0248e0baad0d74713fae9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#             var marker_a38f2f4b67509f8e1e740b274e27b899 = L.marker(
#                 [27.985688, 86.9163367],
#                 {}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#         var popup_99c04461fc1ef15c21b84300d9d15c64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ca6e0567992dd9b0a1c6ce1ddf4005d = $(`&lt;div id=&quot;html_3ca6e0567992dd9b0a1c6ce1ddf4005d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Himalayas&lt;/div&gt;`)[0];
#                 popup_99c04461fc1ef15c21b84300d9d15c64.setContent(html_3ca6e0567992dd9b0a1c6ce1ddf4005d);
#
#
#
#         marker_a38f2f4b67509f8e1e740b274e27b899.bindPopup(popup_99c04461fc1ef15c21b84300d9d15c64)
#         ;
#
#
#
#
#             var marker_d91ab928c384edfde0b662cf52b0c2ad = L.marker(
#                 [15.3358, 76.4610201],
#                 {}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#         var popup_02f0d209bd7938b73808863a707df190 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2e18023a684289bf782331c8b96c5bc = $(`&lt;div id=&quot;html_b2e18023a684289bf782331c8b96c5bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hampi&lt;/div&gt;`)[0];
#                 popup_02f0d209bd7938b73808863a707df190.setContent(html_b2e18023a684289bf782331c8b96c5bc);
#
#
#
#         marker_d91ab928c384edfde0b662cf52b0c2ad.bindPopup(popup_02f0d209bd7938b73808863a707df190)
#         ;
#
#
#
#
#             var marker_b97666a9337a8331d0ca8bd1052dd7fb = L.marker(
#                 [51.7520131, -1.2578499],
#                 {}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#         var popup_2406e9d284e11ad22f1a7439b57977af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7a1ebb01184f678b01c110bbd77d4ff = $(`&lt;div id=&quot;html_d7a1ebb01184f678b01c110bbd77d4ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oxford&lt;/div&gt;`)[0];
#                 popup_2406e9d284e11ad22f1a7439b57977af.setContent(html_d7a1ebb01184f678b01c110bbd77d4ff);
#
#
#
#         marker_b97666a9337a8331d0ca8bd1052dd7fb.bindPopup(popup_2406e9d284e11ad22f1a7439b57977af)
#         ;
#
#
#
#
#             var marker_2f7a31e4b758e9592b1c69fd12ce421c = L.marker(
#                 [19.0403003, 72.91503446461815],
#                 {}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#         var popup_95486b45849f36a040bac7368ae87e59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bf248c28cdfa6de094688c59bdf216c = $(`&lt;div id=&quot;html_6bf248c28cdfa6de094688c59bdf216c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tukaram&lt;/div&gt;`)[0];
#                 popup_95486b45849f36a040bac7368ae87e59.setContent(html_6bf248c28cdfa6de094688c59bdf216c);
#
#
#
#         marker_2f7a31e4b758e9592b1c69fd12ce421c.bindPopup(popup_95486b45849f36a040bac7368ae87e59)
#         ;
#
#
#
#
#             var marker_544014f7b127114967291d90dc31cc0b = L.marker(
#                 [24.5201207, 81.13354895808493],
#                 {}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#         var popup_5dd24ddfeb4b958322334fd792324373 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d3775663e813b115acd5db1c2c8b609 = $(`&lt;div id=&quot;html_3d3775663e813b115acd5db1c2c8b609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deora&lt;/div&gt;`)[0];
#                 popup_5dd24ddfeb4b958322334fd792324373.setContent(html_3d3775663e813b115acd5db1c2c8b609);
#
#
#
#         marker_544014f7b127114967291d90dc31cc0b.bindPopup(popup_5dd24ddfeb4b958322334fd792324373)
#         ;
#
#
#
#
#             var marker_c287ff6ceca886880fb79f03046065f8 = L.marker(
#                 [22.3511148, 78.6677428],
#                 {}
#             ).addTo(map_8cc8baf50a98ff89eb7e5e45507af612);
#
#
#         var popup_49925738c5d78d81363a3f74

# %%
locations = find_locations('A_Room_With_a_View.txt')

# %%
data = []

for a in locations:
    url = f'https://nominatim.openstreetmap.org/search?q={a}&format=json'

    response = requests.get( url ) # The spaces in each address are automatically encoded as '%20' by requests
    json_data = response.json()
    # json_data is a list of results; we assume that the first result is always correct(!)
    if len(json_data)>0:
        latitude = json_data[0]['lat']
        longitude = json_data[0]['lon']
        data.append( [latitude,longitude,a] )
# Out:
# St. Francis
# the Tuscan Plain
# Piazza
# Carrara
# Apollo
# England
# Sunset
# Ireland
# the River Arno
# Bedfordshire
# Alps
# Arno
# Delphi
# Saturn
# the Sacred Lake
# Italy
# Prato
# Weald
# Brighton
# Dover
# Brixton
# Renaissance
# Hullo
# Athens
# Urbino
# the Piazza Signoria
# Ponte alle Grazie
# San Miniato
# Dorking
# Cinque
# Signora
# Greece
# Malea
# Windy Corner
# Metropolis
# Bertolini
# Amalfi
# Rome
# Tunbridge Wells
# S.W
# Lakes
# Surrey
# Florence
# the Holy Water
# Euphemia
# Loggia
# Settignano
# Santa Croce
# the Sussex Weald
# Modena
# Suburbia
# Cissie Villa
# Mediterranean
# Bloomsbury
# Europe
# the South Downs
# Fiesole
# St. Peter's
# Asia
# Nottingham
# the C. O. S.
# Miss Honeychurch
# Venice
# Northern Italy
# the South - Eastern
# Perugia
# the Saronic gulf
# London
# Tuscany
# the Illyrian coast
# Paradise
# South
# The Sacred Lake
# Charlotte
# Honeychurch
# Gotterdammerung
# Constantinople
# Baedeker

# %%
map = folium.Map(location=[43.77546654490791, 11.253323949853995],
tiles = 'OpenStreetMap' ,
    zoom_start=6)

for point in data:
    folium.Marker([point[0],point[1]],
        popup = point[2] ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4 = L.map(
#                 &quot;map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4&quot;,
#                 {
#                     center: [43.77546654490791, 11.253323949853995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d11f9981900bc4522dc005ec6ba777b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#             var marker_c6dacae48af47d3f9b7994b72f8896d9 = L.marker(
#                 [35.0153956, -90.7263194],
#                 {}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#         var popup_df212aa0160edbf569dff17ede6259e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4d43c1cb02947c54541106c07886c7d = $(`&lt;div id=&quot;html_c4d43c1cb02947c54541106c07886c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St. Francis&lt;/div&gt;`)[0];
#                 popup_df212aa0160edbf569dff17ede6259e5.setContent(html_c4d43c1cb02947c54541106c07886c7d);
#
#
#
#         marker_c6dacae48af47d3f9b7994b72f8896d9.bindPopup(popup_df212aa0160edbf569dff17ede6259e5)
#         ;
#
#
#
#
#             var marker_e819b42076f633834f31267f181c2f78 = L.marker(
#                 [37.385946, 14.367174],
#                 {}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#         var popup_724f49f3a620a41929b29fa1408d7f09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76de5c6423ce03106a427f3cc72bb823 = $(`&lt;div id=&quot;html_76de5c6423ce03106a427f3cc72bb823&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Piazza&lt;/div&gt;`)[0];
#                 popup_724f49f3a620a41929b29fa1408d7f09.setContent(html_76de5c6423ce03106a427f3cc72bb823);
#
#
#
#         marker_e819b42076f633834f31267f181c2f78.bindPopup(popup_724f49f3a620a41929b29fa1408d7f09)
#         ;
#
#
#
#
#             var marker_2415733b73e1cf8c0ff312212b993ca1 = L.marker(
#                 [44.0771026, 10.096726],
#                 {}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#         var popup_c61e49479acd85b784c5f552d4a50c8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47ea1e2b88fe28ff5df97a38d990a06e = $(`&lt;div id=&quot;html_47ea1e2b88fe28ff5df97a38d990a06e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Carrara&lt;/div&gt;`)[0];
#                 popup_c61e49479acd85b784c5f552d4a50c8c.setContent(html_47ea1e2b88fe28ff5df97a38d990a06e);
#
#
#
#         marker_2415733b73e1cf8c0ff312212b993ca1.bindPopup(popup_c61e49479acd85b784c5f552d4a50c8c)
#         ;
#
#
#
#
#             var marker_c34e0dfa78dd27270569293fac3f37c2 = L.marker(
#                 [40.5826289, -79.5670341],
#                 {}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#         var popup_3c881fb4f249b9a814e8f031b68c936b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb43ce1c03b9939462e5cac01a18177e = $(`&lt;div id=&quot;html_cb43ce1c03b9939462e5cac01a18177e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Apollo&lt;/div&gt;`)[0];
#                 popup_3c881fb4f249b9a814e8f031b68c936b.setContent(html_cb43ce1c03b9939462e5cac01a18177e);
#
#
#
#         marker_c34e0dfa78dd27270569293fac3f37c2.bindPopup(popup_3c881fb4f249b9a814e8f031b68c936b)
#         ;
#
#
#
#
#             var marker_d5395d66fb8a7e7f8aa110c4bb5e075f = L.marker(
#                 [52.5310214, -1.2649062],
#                 {}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#         var popup_1d89693953e2421ebcec64a6e603ef95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_276f08224b811322ed952f158b6d72f0 = $(`&lt;div id=&quot;html_276f08224b811322ed952f158b6d72f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;England&lt;/div&gt;`)[0];
#                 popup_1d89693953e2421ebcec64a6e603ef95.setContent(html_276f08224b811322ed952f158b6d72f0);
#
#
#
#         marker_d5395d66fb8a7e7f8aa110c4bb5e075f.bindPopup(popup_1d89693953e2421ebcec64a6e603ef95)
#         ;
#
#
#
#
#             var marker_a332aec15e398ec966addedb691d3203 = L.marker(
#                 [25.7040213, -80.35225366277555],
#                 {}
#             ).addTo(map_4e1cd0fb53eb1fbc0eb8431fd6c7a3d4);
#
#
#         var popup_2543b16aef4bfb60adc66
