# %% [markdown]
# ## Data acquisition via the Europeana API
#
# This notebook explains how you can extract data from the Europeana platform via its APIs. In most cases, the data that are made available via the Europeana APIs can be viewed on Europeana's public website as well. To get a sense of the type of data that are available, open the link below and have look at the metadata.
#
#
# [https://www.europeana.eu/en/item/598/9939757197402711_item_2420001](https://www.europeana.eu/en/item/598/9939757197402711_item_2420001)

# %% [markdown]
# If you want to anaylyse these data, however, it is generally more effective to extract these values as raw data. This can be accomplished via two APIs. Europeana maintains a [Search API](https://pro.europeana.eu/page/search) and a [Record API](https://pro.europeana.eu/page/record).
#
# The record API, firstly, enables you to retrieve the values that have been collected and created in individual records. It works with the following paramaters:
#
# * record_format: 'json' or 'rdf'
# * item_id: The full identifier of the record. This typically inculdes the identifier for the content provider.
# * profile: Value 'standard'
#
# You can view the raw data of the record you looked at earlier by clicking the URL that is generated by the cell below.

# %%
import requests
import re
from os.path import join
import json

from credentials import api_key
base_url_record = 'https://api.europeana.eu/record/v2/'
record_format = 'json'
item_id = '598/9939757197402711_item_2420001'
profile = 'standard'

api_call = f'{base_url_record}{item_id}.{record_format}?profile={profile}&wskey={api_key}'

print(api_call)
# Out:
# https://api.europeana.eu/record/v2/598/9939757197402711_item_2420001.json?profile=standard&wskey=ineternates

# %% [markdown]
# ## Exercise
#
# Try to obtain raw data about another object in Europeana. You can work with one of the objects below, for example.
#
# * https://www.europeana.eu/en/item/598/9939757142102711_item_2709295
# * https://www.europeana.eu/item/598/9939757129002711_item_935820
#
# The code that was given exports the the data in the JSON format. Also try to view the data in RDF/XML format.

# %% [markdown]
# The cells below give an impression of the kinds of values that are available in Europeana records. Note that the code only shows you a small fraction of the data values that are actually available.

# %%
base_url_record = 'https://api.europeana.eu/record/v2/'
record_format = 'json'
item_id = '598/9939757129002711_item_935820'
profile = 'standard'

api_call = f'{base_url_record}{item_id}.{record_format}?profile={profile}&wskey={api_key}'
print(api_call)

response = requests.get(api_call)

if response:
    api_data = response.json()
# Out:
# https://api.europeana.eu/record/v2/598/9939757129002711_item_935820.json?profile=standard&wskey=ineternates

# %%
agents = dict()

for agent in api_data['object']['agents']:
    if 'prefLabel' in agent:
        label = agent['prefLabel']['en'][0]
        about = agent['about']
        agents[about] = label

for agent in agents:
    print(f'{agent}\t{agents[agent]}')
    
        
places = dict()

for place in api_data['object']['places']:

    if 'en' in place['prefLabel']:
        label = place['prefLabel']['en'][0]
    else:
        label = ''
        
    about = place['about']
    places[about] = label
        
print('\n')

for place in places:
    print(f'{place}\t{places[place]}')
    
        
for proxy in api_data['object']['proxies']:

    if 'year' in proxy:
        print('Year: ' + proxy['year']['def'][0])
    print('Language: ' + proxy['dcLanguage']['def'][0])
    
    if 'dcDescription' in proxy:
        if 'en' in proxy['dcDescription']:
            for note in proxy['dcDescription']['en']:
                print(note)
                
    if 'dctermsExtent' in proxy:
        if 'en' in proxy['dctermsExtent']:
            for note in proxy['dcDescription']['en']:
                print(note)
# Out:
# http://www.wikidata.org/entity/Q892143	Bonaventura Vulcanius
#
#
# http://data.europeana.eu/place/85	France
# http://vocab.getty.edu/tgn/1000070	France
# https://sws.geonames.org/2751772/
# https://sws.geonames.org/11874022/
# Year: 1425
# Language: lat
# Language: lat
# decorated initials, coloured symbols in the tables
# handwritten, littera textualis
# 17 lines, written space varies
# Binding: Medieval binding, contemporary (so-called belt book).
# Description (Senguerdius & 1716): http://hdl.handle.net/1887.1/item:290399
# Description (Molhuysen 1910): http://hdl.handle.net/1887.1/item:3151050
# Description (Catalogus compendiarius 1932): http://hdl.handle.net/1887.1/item:491294
# Also described by MMDC and A.W. Byvanckgenootschap (database RKD, The Hague).
# Restored (report available), 1986
# decorated initials, coloured symbols in the tables
# handwritten, littera textualis
# 17 lines, written space varies
# Binding: Medieval binding, contemporary (so-called belt book).
# Description (Senguerdius & 1716): http://hdl.handle.net/1887.1/item:290399
# Description (Molhuysen 1910): http://hdl.handle.net/1887.1/item:3151050
# Description (Catalogus compendiarius 1932): http://hdl.handle.net/1887.1/item:491294
# Also described by MMDC and A.W. Byvanckgenootschap (database RKD, The Hague).
# Restored (report available), 1986

# %% [markdown]
# ## Search API
#
# The search API can be used to select records with specific properties in the Europeana database. Te query below selects all the items from Leiden University that are part of the [ARMA collection](https://www.medieval-reads.eu/home).

# %%
base_url = 'https://api.europeana.eu/record/v2/search.json?'
profile= 'standard' 
qf= 'Leiden%20University%20Libraries'
query='middle%20ages'
rows=100
start=1

api_call = f'{base_url}profile={profile}&qf={qf}&query={query}&rows={rows}&start={start}&wskey={api_key}'
print(api_call)

response = requests.get(api_call)

if response:
    api_data = response.json()
    if len(api_data)>0:
        print(f"{api_data['totalResults']} results")
# Out:
# https://api.europeana.eu/record/v2/search.json?profile=standard&qf=Leiden%20University%20Libraries&query=middle%20ages&rows=100&start=1&wskey=ineternates
# 610 results

# %% [markdown]
# To experiment with the Search API, change the value of the query parameter below.

# %%
base_url = 'https://api.europeana.eu/record/v2/search.json?'
profile= 'standard' 
query='banana'
rows=100
start=1

api_call = f'{base_url}profile={profile}&query={query}&rows={rows}&start={start}&wskey={api_key}'
print(api_call)

response = requests.get(api_call)

if response:
    api_data = response.json()
    if len(api_data)>0:
        print(f"{api_data['totalResults']} results")
# Out:
# https://api.europeana.eu/record/v2/search.json?profile=standard&query=banana&rows=100&start=1&wskey=ineternates
# 4466 results

# %%
if len(api_data)>0:
    for item in api_data['items']:
        print(item['guid'], end = '\n\n')
# Out:
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000072080001100?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000060516000100?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/202/item_INVW6S6ZRPVPQWB4VRGQTH7OPM7B77IP?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/08611/censorship74237?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/08611/censorship10017?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/08611/censorship49695?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/08611/censorship29579?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2048001/AP_10343882?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/08611/censorship81106?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2021009/_02B0A949B325DB1F2A8F1683945D478F?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2021009/_3C7E40E2A14F2649E329E24F385D9CD8?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2026007/fabritiusweb_LinkToVubis_csp_DataBib_2_9530_Language_dut?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000040795000100?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000075803000600?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000036004001500?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2024904/https___www_topfoto_co_uk_asset_1830390?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2021009/_4001D48E59231484612D566FE8AA3E8A?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/08711/https___www_biodiversitylibrary_org_item_83027?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/465/1048819?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/117/_95419643_A109_407E_B999_BBF752B8FD9F?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2048087/ProvidedCHO_Horniman_Museum_and_Gardens_http___collections_horniman_ac_uk_objects_77060?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2048087/ProvidedCHO_Horniman_Museum_and_Gardens_http___collections_horniman_ac_uk_objects_77059?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/04802/7B6AAFE2E6E71126869ABA39BB6176B1F51FFE3D?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000071733000300?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2023865/objekte_digi_einzBild_php_s_1_pi_913_2007SSM283_14?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2058626/locloud_flickr_11097048054?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000070430000100?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/446/MIL0871906?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2023865/objekte_digi_einzBild_php_s_1_pi_913_2007SSM1543_10?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/90402/RP_F_F01147_20_2?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item