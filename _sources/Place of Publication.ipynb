# %% [markdown]
# # STCN: Analyses of places of publication

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from IPython.core.display import display, HTML
import pandas as pd
import numpy as np
import json
import re
from stcn import *
import folium
from tqdm import tqdm
from collections import Counter

# %% [markdown]
# ## Place of creation
#
# The following SPARQL query requests data about the titles published in the fifteenth or sixteenth century from the [Short Title Catalogue of the Netherlands](https://data.cerl.org/stcn/)

# %%
query = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX kb: <http://data.bibliotheken.nl/def#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT * WHERE {

# ?resource schema:mainEntityOfPage ?mainEntity .
# ?mainEntity schema:isPartOf <http://data.bibliotheken.nl/id/dataset/stcn>  . 
  
# ?resource schema:publication ?publ .
# ?resource schema:name ?title . 

OPTIONAL {
# ?resource schema:alternateName ?alt_title . }

OPTIONAL {
# ?publ schema:startDate ?publ_year . 
# ?publ schema:description ?imprint . 
# ?publ schema:publishedBy ?publisher . 
# ?publisher schema:name ?publ_name .
# ?publisher schema:location ?location_node .
# ?location_node schema:address ?address .
# ?address schema:addressLocality ?place . 
} .

FILTER( regex(?publ_year, "^1[45]", "i") ) .

} 

"""
df = run_query(query)

# %%
nr_results = df.drop_duplicates(subset=['resource.value']).shape[0]
print(f'The query returns information about {nr_results} titles.')
# Out:
# The query returns information about 8332 titles.

# %% [markdown]
# In some records, the year of publication is truncated. The cell below replaces the truncated values to the number '5', to make it easier to process those values.

# %%
def standardise_date(row):
    if re.search(r'x' , row['publ_year.value'] , re.IGNORECASE):
        row['publ_year.value'] = re.sub( 'x' , '5' , row['publ_year.value'] , re.IGNORECASE)
    
    if re.search(r'\d{4}' , row['publ_year.value']):
        return int(row['publ_year.value'])
    else:
        return np.nan
    
    
df['datetime'] = df.apply(standardise_date, axis=1)
df=df.dropna(subset=['datetime'])

# %% [markdown]
# The file <a href="stcn_gis.tsv" target="_new">stcn_gis.tsv</a> contains an list of all the cities that are mentioned in the STCN. Additionally, it contains the latitude and the longitude of these locations, and information about the countries these cities are in. The assignment of the country is based on today's political borders. The informatinon was created via [geocoding](https://developers.arcgis.com/documentation/mapping-apis-and-services/geocoding/).
#
#
# The file 'stcn_gis.tsv' is read using the code below.

# %%
locations = pd.read_csv('stcn_gis.tsv',sep='\t')

gis = dict()
country = dict()

for i,row in locations.iterrows():
    gis[row['name']] = [row['latitude'],row['longitude']]
    if re.search( r',' ,row['display_name'] ):
        parts = re.split( r',' , row['display_name'] )
        country_name = parts[-1].strip()
    else:
        country_name = row['display_name']
    if re.search(r'\/', country_name ):
        country_name = country_name[ country_name.rindex('/')+1:]
    country[ row['name'] ] = country_name.strip()

# %% [markdown]
# The following code converts the STCN data to the JSON format, to ease the processing of these data. The place names are also enriched with the geographic coordinates. Running the cell may take time. The data set is written to the disk under the file name 'stcn_locations.js'.

# %%
unique_ids = df.sort_values('datetime')['resource.value'].unique()

data = []

def print_value(value):
    if pd.isna(value):
        return ''
    else:
        return value
    
def get_values(df,field,fields_dict):
    rows = df.drop_duplicates(field)
    all_rows = []
    for i,row in rows.iterrows():
        values = dict()
        for f in fields_dict:
            values[fields_dict[f]] = print_value(row[f])
        all_rows.append(values)
    return all_rows    


for resource in tqdm(unique_ids):

    record = dict()
    record['ppn'] = resource
    #print(resource)

    df_resource = df[ df['resource.value'] == resource ]
    
    record['title'] = df_resource.iloc[0]['title.value']
    if not pd.isna(df_resource.iloc[0]['alt_title.value']):
        record['alternative_title'] = df_resource.iloc[0]['alt_title.value']
    record['year'] = df_resource.iloc[0]['publ_year.value']
    
    ## Publishers
    unique_id = 'publisher.value'
    fields_dict = { 'publisher.value':'ppn',
        'publ_name.value':'name' ,
        'place.value':'place' , 
        
    }
    
    all_publishers = get_values(df_resource,unique_id,fields_dict)
    record['publishers'] = all_publishers
    
    place = df_resource.iloc[0]['place.value']
    coordinates = gis.get(place)

    if coordinates:
        record['location'] = { 
            'place_name' : place , 
            'latitude':coordinates[0] , 
                             'longitude':coordinates[1] , 
                             'country':country.get(place)}

    data.append(record)
    
with open('stcn_locations.json','w',encoding='utf-8') as out:
    out.write(json.dumps(data,indent=4))
    
f = open('stcn_locations.json')
json_data = json.load(f)
f.close()
# Out:
# 100%|██████████████████████████████████████| 6442/6442 [00:11<00:00, 548.56it/s]

# %%
def singular_plural(noun,count):
    if count>1:
        noun=noun+'s'
    return noun
        
def print_map_nl(place_count,out_file='map.html'):
    
    map = folium.Map( location=[51.875127716984274, 5.360011275145361] , 
    width="%100",
    height="%100",
    zoom_start=8)

    for place,count in place_count.most_common():

        folium.Circle(
            location=[ gis[place][0], gis[place][1]],
            radius= count * 25 ,
            color='#1827c9',
            fill=False ,
            fill_opacity = 0.5,
            fill_color = '#c72d22' ,
            weight = 2 ,
            popup = f'{place}: {count} {singular_plural("title",count)}.').add_to(map)

    map.save(out_file)
    return map
 
def print_map_world(place_count,out_file='map.html'):
    map = folium.Map( location=[52.157004081232024, 4.495349166689632] , 
    width="%100",
    height="%100",
    zoom_start=3)

    for place,count in place_count.most_common():

        folium.Circle(
            location=[ gis[place][0], gis[place][1]],
            radius= count*2500 ,
            color='#1827c9',
            fill=False ,
            fill_opacity = 0.5,
            fill_color = '#c72d22' ,
            weight = 2 ,
            popup = f'{place}: {count} {singular_plural("title",count)}.').add_to(map)

    map.save(out_file)
    return map

# %% [markdown]
# How did the art of printing spread across the low countries? The code below identifies the cities that are mentioned in the export from the STCN. The analyses is broken down by periods of 25 years.

# %%
cities = []
from IPython.display import display

period_length = 25

for year in range( 1450 , 1600, period_length ):
    end = year+period_length
    out_file= f'map_{year}-{end}.html'
    
    print(f'\n{year}-{end}\n\n')
    
    for title in json_data:
        title['year'] = re.sub(r'X','5',title['year'],re.IGNORECASE)
        if 'location' in title:
            if int(title['year']) >= year and int(title['year'])<end and (title['location']['country'] == 'Nederland' or title['location']['country'] == 'Belgien'):
                cities.append(title['location']['place_name'])
                #print(title['location']['place_name'])

    place_count = Counter(cities)
    folium_map = print_map_nl(place_count,out_file= out_file)
    display(folium_map)
# Out:
# 1450-1475
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a6d8c85a835207b6a838569e9cd1a93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a6d8c85a835207b6a838569e9cd1a93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a6d8c85a835207b6a838569e9cd1a93 = L.map(
#                 &quot;map_0a6d8c85a835207b6a838569e9cd1a93&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93b17334feee014d32a21d8bd155132e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a6d8c85a835207b6a838569e9cd1a93);
#
#
#             var circle_c948b247dffc0d0a17e6a3bab3afbb9e = L.circle(
#                 [52.0907006, 5.1215634],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 450, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0a6d8c85a835207b6a838569e9cd1a93);
#
#
#         var popup_18ddafdebbe6b4b2249768cadf3b7145 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db4441ed1b820cb84ea4ff329f779d4c = $(`&lt;div id=&quot;html_db4441ed1b820cb84ea4ff329f779d4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Utrecht: 18 titles.&lt;/div&gt;`)[0];
#                 popup_18ddafdebbe6b4b2249768cadf3b7145.setContent(html_db4441ed1b820cb84ea4ff329f779d4c);
#
#
#
#         circle_c948b247dffc0d0a17e6a3bab3afbb9e.bindPopup(popup_18ddafdebbe6b4b2249768cadf3b7145)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# 1475-1500
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b1ee7911e12f7318a83ce77ce57ad24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b1ee7911e12f7318a83ce77ce57ad24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b1ee7911e12f7318a83ce77ce57ad24 = L.map(
#                 &quot;map_3b1ee7911e12f7318a83ce77ce57ad24&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fd7b7d21a891b7d0dcbc2023435bbc3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b1ee7911e12f7318a83ce77ce57ad24);
#
#
#             var circle_3a0f66323a30ac72fc3083d247a4f8a0 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7300, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_3b1ee7911e12f7318a83ce77ce57ad24);
#
#
#         var popup_00ea5af1196dc29e391ea028f36cc090 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad11bb04ff8a00b10f1224ed27678593 = $(`&lt;div id=&quot;html_ad11bb04ff8a00b10f1224ed27678593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 292 titles.&lt;/div&gt;`)[0];
#                 popup_00ea5af1196dc29e391ea028f36cc090.setContent(html_ad11bb04ff8a00b10f1224ed27678593);
#
#
#
#         circle_3a0f66323a30ac72fc3083d247a4f8a0.bindPopup(popup_00ea5af1196dc29e391ea028f36cc090)
#         ;
#
#
#
#
#             var circle_f7765bcf455136bbb458f1a99160d5b5 = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2575, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_3b1ee7911e12f7318a83ce77ce57ad24);
#
#
#         var popup_134f64f96522a22503683bad3e695afd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af450950af682cd763db4e225a45c12c = $(`&lt;div id=&quot;html_af450950af682cd763db4e225a45c12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 103 titles.&lt;/div&gt;`)[0];
#                 popup_134f64f96522a22503683bad3e695afd.setContent(html_af450950af682cd763db4e225a45c12c);
#
#
#
#         circle_f7765bcf455136bbb458f1a99160d5b5.bindPopup(popup_134f64f96522a22503683bad3e695afd)
#         ;
#
#
#
#
#             var circle_e0f71d04a45ddc58d5e255c828f332eb = L.circle(
#                 [52.0114922, 4.7106094],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_3b1ee7911e12f7318a83ce77ce57ad24);
#
#
#         var popup_4a65d2087cde06315d50365075786d41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc2e1a1c71bc0e8ddfbc2e9b43bbaf08 = $(`&lt;div id=&quot;html_fc2e1a1c71bc0e8ddfbc2e9b43bbaf08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gouda: 72 titles.&lt;/div&gt;`)[0];
#                 popup_4a65d2087cde06315d50365075786d41.setContent(html_fc2e1a1c71bc0e8ddfbc2e9b43bbaf08);
#
#
#
#         circle_e0f71d04a45ddc58d5e255c828f332eb.bindPopup(popup_4a65d2087cde06315d50365075786d41)
#         ;
#
#
#
#
#             var circle_da7bf8e0c54a18e4e47fc9468609c15c = L.circle(
#                 [52.5089759, 6.0943765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quo
# 1500-1525
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85b40db2ef10cf626322f5d0d783fea6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85b40db2ef10cf626322f5d0d783fea6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85b40db2ef10cf626322f5d0d783fea6 = L.map(
#                 &quot;map_85b40db2ef10cf626322f5d0d783fea6&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dae9ec1ea62d58991c794f674884fabd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_85b40db2ef10cf626322f5d0d783fea6);
#
#
#             var circle_0d37bc3c4bc18cfdb02dc70029061a93 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21050, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_85b40db2ef10cf626322f5d0d783fea6);
#
#
#         var popup_437a3abee865c33d807579bd264d0b67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dda0cf91470f8aa29a99fd8a51041cf0 = $(`&lt;div id=&quot;html_dda0cf91470f8aa29a99fd8a51041cf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 842 titles.&lt;/div&gt;`)[0];
#                 popup_437a3abee865c33d807579bd264d0b67.setContent(html_dda0cf91470f8aa29a99fd8a51041cf0);
#
#
#
#         circle_0d37bc3c4bc18cfdb02dc70029061a93.bindPopup(popup_437a3abee865c33d807579bd264d0b67)
#         ;
#
#
#
#
#             var circle_7653b5d020075546b1c74d9220d30932 = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2900, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_85b40db2ef10cf626322f5d0d783fea6);
#
#
#         var popup_ed229c98dd12f903c6d0d09a3b362897 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77c899ddbec26c02623e46a49439e8ce = $(`&lt;div id=&quot;html_77c899ddbec26c02623e46a49439e8ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 116 titles.&lt;/div&gt;`)[0];
#                 popup_ed229c98dd12f903c6d0d09a3b362897.setContent(html_77c899ddbec26c02623e46a49439e8ce);
#
#
#
#         circle_7653b5d020075546b1c74d9220d30932.bindPopup(popup_ed229c98dd12f903c6d0d09a3b362897)
#         ;
#
#
#
#
#             var circle_2f17474146bd8a01bd3676173e5a30e2 = L.circle(
#                 [52.5089759, 6.0943765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2575, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_85b40db2ef10cf626322f5d0d783fea6);
#
#
#         var popup_605fa562264a2a638629f94e8108de19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b07447a1b810e3cbe5a1128b998f4d78 = $(`&lt;div id=&quot;html_b07447a1b810e3cbe5a1128b998f4d78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zwolle: 103 titles.&lt;/div&gt;`)[0];
#                 popup_605fa562264a2a638629f94e8108de19.setContent(html_b07447a1b810e3cbe5a1128b998f4d78);
#
#
#
#         circle_2f17474146bd8a01bd3676173e5a30e2.bindPopup(popup_605fa562264a2a638629f94e8108de19)
#         ;
#
#
#
#
#             var circle_19aeb232696d0bbbcb27b9b8f35d6512 = L.circle(
#                 [52.0114922, 4.7106094],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&
# 1525-1550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_860e52dcbee1df0fdf8f5489bd84dd2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_860e52dcbee1df0fdf8f5489bd84dd2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_860e52dcbee1df0fdf8f5489bd84dd2f = L.map(
#                 &quot;map_860e52dcbee1df0fdf8f5489bd84dd2f&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7563ce0562ef5a9ca8abdbb31572aa5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_860e52dcbee1df0fdf8f5489bd84dd2f);
#
#
#             var circle_5b5eaf7edba90633fc8e6eff065e0c66 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22575, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_860e52dcbee1df0fdf8f5489bd84dd2f);
#
#
#         var popup_0582f9130d93b817d3b6475a8965ee86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7e4cdb19c13d2a76eb49f04f364a838 = $(`&lt;div id=&quot;html_d7e4cdb19c13d2a76eb49f04f364a838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 903 titles.&lt;/div&gt;`)[0];
#                 popup_0582f9130d93b817d3b6475a8965ee86.setContent(html_d7e4cdb19c13d2a76eb49f04f364a838);
#
#
#
#         circle_5b5eaf7edba90633fc8e6eff065e0c66.bindPopup(popup_0582f9130d93b817d3b6475a8965ee86)
#         ;
#
#
#
#
#             var circle_c35a4b0dc0e70594ddd2915e942b8070 = L.circle(
#                 [51.2211097, 4.3997081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4225, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_860e52dcbee1df0fdf8f5489bd84dd2f);
#
#
#         var popup_6b579249e87530d9fcd3aa1eab337ab1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d87275cd5ff17f5e81f11eb98f0ae5f = $(`&lt;div id=&quot;html_4d87275cd5ff17f5e81f11eb98f0ae5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Antwerpen: 169 titles.&lt;/div&gt;`)[0];
#                 popup_6b579249e87530d9fcd3aa1eab337ab1.setContent(html_4d87275cd5ff17f5e81f11eb98f0ae5f);
#
#
#
#         circle_c35a4b0dc0e70594ddd2915e942b8070.bindPopup(popup_6b579249e87530d9fcd3aa1eab337ab1)
#         ;
#
#
#
#
#             var circle_e93204a1740d0f781ec0e4b31f0a36d9 = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3275, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_860e52dcbee1df0fdf8f5489bd84dd2f);
#
#
#         var popup_336f55abcf723737f4f6342bc18e2316 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9ca3ff23ee255526b3ad5494d0c9835 = $(`&lt;div id=&quot;html_e9ca3ff23ee255526b3ad5494d0c9835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 131 titles.&lt;/div&gt;`)[0];
#                 popup_336f55abcf723737f4f6342bc18e2316.setContent(html_e9ca3ff23ee255526b3ad5494d0c9835);
#
#
#
#         circle_e93204a1740d0f781ec0e4b31f0a36d9.bindPopup(popup_336f55abcf723737f4f6342bc18e2316)
#         ;
#
#
#
#
#             var circle_af40c8b5cef009f8c388a44c981f12fb = L.circle(
#                 [52.1518157, 4.4811088666204295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &q
# 1550-1575
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff2435f21caef04e7850fdbc27d71493 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff2435f21caef04e7850fdbc27d71493&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff2435f21caef04e7850fdbc27d71493 = L.map(
#                 &quot;map_ff2435f21caef04e7850fdbc27d71493&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2edfa660876eefb098664166a5a19115 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff2435f21caef04e7850fdbc27d71493);
#
#
#             var circle_7ee9b52ac09edf1222614228b8c422a1 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23100, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ff2435f21caef04e7850fdbc27d71493);
#
#
#         var popup_11101593a8f75229a88c8c603632f691 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6672ac612b1e6312e51425d4b3377e5c = $(`&lt;div id=&quot;html_6672ac612b1e6312e51425d4b3377e5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 924 titles.&lt;/div&gt;`)[0];
#                 popup_11101593a8f75229a88c8c603632f691.setContent(html_6672ac612b1e6312e51425d4b3377e5c);
#
#
#
#         circle_7ee9b52ac09edf1222614228b8c422a1.bindPopup(popup_11101593a8f75229a88c8c603632f691)
#         ;
#
#
#
#
#             var circle_fab579b407529e8b9a21b3fa4e1a2289 = L.circle(
#                 [51.2211097, 4.3997081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8700, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ff2435f21caef04e7850fdbc27d71493);
#
#
#         var popup_c2190e54ec2680f4ca3fa023df4903d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53ed3df09a7e0088d62fe945233c8910 = $(`&lt;div id=&quot;html_53ed3df09a7e0088d62fe945233c8910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Antwerpen: 348 titles.&lt;/div&gt;`)[0];
#                 popup_c2190e54ec2680f4ca3fa023df4903d2.setContent(html_53ed3df09a7e0088d62fe945233c8910);
#
#
#
#         circle_fab579b407529e8b9a21b3fa4e1a2289.bindPopup(popup_c2190e54ec2680f4ca3fa023df4903d2)
#         ;
#
#
#
#
#             var circle_8e88c52a8f6e43c0a1796bde3fdadf74 = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ff2435f21caef04e7850fdbc27d71493);
#
#
#         var popup_2b43efaf3935ac6f4fa4d34e0a5baa30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82d41f11af4aaee6ca22891ff1bb7cd4 = $(`&lt;div id=&quot;html_82d41f11af4aaee6ca22891ff1bb7cd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 192 titles.&lt;/div&gt;`)[0];
#                 popup_2b43efaf3935ac6f4fa4d34e0a5baa30.setContent(html_82d41f11af4aaee6ca22891ff1bb7cd4);
#
#
#
#         circle_8e88c52a8f6e43c0a1796bde3fdadf74.bindPopup(popup_2b43efaf3935ac6f4fa4d34e0a5baa30)
#         ;
#
#
#
#
#             var circle_8f9a87b36acc755cb8d38b4d0ca0a46b = L.circle(
#                 [52.1518157, 4.4811088666204295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &q
# 1575-1600
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4c346f118c7cbf139dd3e68d3ec4f08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4c346f118c7cbf139dd3e68d3ec4f08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4c346f118c7cbf139dd3e68d3ec4f08 = L.map(
#                 &quot;map_d4c346f118c7cbf139dd3e68d3ec4f08&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88fc42f184f4e37f3712fa8f1ec048a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4c346f118c7cbf139dd3e68d3ec4f08);
#
#
#             var circle_a99c1f1a1b13e927f382be91aa84013c = L.circle(
#                 [52.1518157, 4.4811088666204295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 36675, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_d4c346f118c7cbf139dd3e68d3ec4f08);
#
#
#         var popup_861478ab488bfb5072e1338e36690d3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09fc4c082ae186b86c2cc883ce473c05 = $(`&lt;div id=&quot;html_09fc4c082ae186b86c2cc883ce473c05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leiden: 1467 titles.&lt;/div&gt;`)[0];
#                 popup_861478ab488bfb5072e1338e36690d3d.setContent(html_09fc4c082ae186b86c2cc883ce473c05);
#
#
#
#         circle_a99c1f1a1b13e927f382be91aa84013c.bindPopup(popup_861478ab488bfb5072e1338e36690d3d)
#         ;
#
#
#
#
#             var circle_524f03b3f922c9d01c45fe95aa47470e = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23825, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_d4c346f118c7cbf139dd3e68d3ec4f08);
#
#
#         var popup_c33b40c453403e3fa48a22521c2eb9f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36cedced0a20b29b5fc180c222a4396e = $(`&lt;div id=&quot;html_36cedced0a20b29b5fc180c222a4396e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 953 titles.&lt;/div&gt;`)[0];
#                 popup_c33b40c453403e3fa48a22521c2eb9f2.setContent(html_36cedced0a20b29b5fc180c222a4396e);
#
#
#
#         circle_524f03b3f922c9d01c45fe95aa47470e.bindPopup(popup_c33b40c453403e3fa48a22521c2eb9f2)
#         ;
#
#
#
#
#             var circle_2ca10baab5ae59f403f4d47c87a6632e = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14125, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_d4c346f118c7cbf139dd3e68d3ec4f08);
#
#
#         var popup_4341bd7a6708d0305332d96474ff56c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f7b299fff587f9236232468fbc734ca = $(`&lt;div id=&quot;html_8f7b299fff587f9236232468fbc734ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 565 titles.&lt;/div&gt;`)[0];
#                 popup_4341bd7a6708d0305332d96474ff56c9.setContent(html_8f7b299fff587f9236232468fbc734ca);
#
#
#
#         circle_2ca10baab5ae59f403f4d47c87a6632e.bindPopup(popup_4341bd7a6708d0305332d96474ff56c9)
#         ;
#
#
#
#
#             var circle_068858980f4c08d7a14db636f578da47 = L.circle(
#                 [51.2211097, 4.3997081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &q

# %% [markdown]
# These maps can also be viewed in a separate window:
#
# * <a target="_new" href="_sources/map_1450-1475.html">1450-1475</a>
# * <a target="_new" href="_sources/map_1475-1500.html">1475-1500</a>
# * <a target="_new" href="_sources/map_1500-1525.html">1500-1525</a>
# * <a target="_new" href="_sources/map_1525-1550.html">1525-1550</a>
# * <a target="_new" href="_sources/map_1550-1575.html">1550-1575</a>
# * <a target="_new" href="_sources/map_1575-1600.html">1575-1600</a>

# %% [markdown]
# ## Printing in Dutch outside of the Low Countries

# %%
cities = []

period_length = 25

for year in range( 1450 , 1600, period_length ):
    end = year+period_length
    print(f'{year}-{end}')
    
    for title in json_data:
        title['year'] = re.sub(r'X','5',title['year'],re.IGNORECASE)
        if 'location' in title:
            if int(title['year']) >= year and int(title['year'])<end and title['location']['country'] != 'Nederland' and title['location']['country'] != 'Belgien':
                if title['location']['place_name'] != 'Place unknown':
                    cities.append(title['location']['place_name'])
                #print(title['location']['place_name'])

    place_count = Counter(cities)


    folium_map = print_map_world(place_count,out_file= f'map_europe_{year}-{end}.html')
    display(folium_map)
# Out:
# 1450-1475
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a83bc3b47b8610ceec0256d948f0811 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a83bc3b47b8610ceec0256d948f0811&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a83bc3b47b8610ceec0256d948f0811 = L.map(
#                 &quot;map_5a83bc3b47b8610ceec0256d948f0811&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d74d7a62dfab20df5d0b6dd3c2755886 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5a83bc3b47b8610ceec0256d948f0811);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# 1475-1500
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efc6c1aa7941844eefcffdf169c5dc64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efc6c1aa7941844eefcffdf169c5dc64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efc6c1aa7941844eefcffdf169c5dc64 = L.map(
#                 &quot;map_efc6c1aa7941844eefcffdf169c5dc64&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53b18333618208fa27b90f3fe7095c8c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efc6c1aa7941844eefcffdf169c5dc64);
#
#
#             var circle_563d87b8a1058c1f4f6d776758f057d8 = L.circle(
#                 [50.0012314, 8.2762513],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_efc6c1aa7941844eefcffdf169c5dc64);
#
#
#         var popup_db4dc31e0d00e0e3670a995f18103782 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44206196a7deca27b4d53b3a7c802f99 = $(`&lt;div id=&quot;html_44206196a7deca27b4d53b3a7c802f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mainz: 1 title.&lt;/div&gt;`)[0];
#                 popup_db4dc31e0d00e0e3670a995f18103782.setContent(html_44206196a7deca27b4d53b3a7c802f99);
#
#
#
#         circle_563d87b8a1058c1f4f6d776758f057d8.bindPopup(popup_db4dc31e0d00e0e3670a995f18103782)
#         ;
#
#
#
#
#             var circle_c86b1cee4d466036e20f39475fc07759 = L.circle(
#                 [53.866444, 10.684738],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_efc6c1aa7941844eefcffdf169c5dc64);
#
#
#         var popup_5b511d45d5035473f76dc0955cd8010a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4af19b889d681fbe16a232d2f009e27e = $(`&lt;div id=&quot;html_4af19b889d681fbe16a232d2f009e27e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lübeck: 1 title.&lt;/div&gt;`)[0];
#                 popup_5b511d45d5035473f76dc0955cd8010a.setContent(html_4af19b889d681fbe16a232d2f009e27e);
#
#
#
#         circle_c86b1cee4d466036e20f39475fc07759.bindPopup(popup_5b511d45d5035473f76dc0955cd8010a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# 1500-1525
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0dc2b48aaa91fa585dea1ffe19c85cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0dc2b48aaa91fa585dea1ffe19c85cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0dc2b48aaa91fa585dea1ffe19c85cb = L.map(
#                 &quot;map_f0dc2b48aaa91fa585dea1ffe19c85cb&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4b96a248157b12c4fcb8c19db03adcc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0dc2b48aaa91fa585dea1ffe19c85cb);
#
#
#             var circle_78efd3fbf536e04dffe6963ee351821f = L.circle(
#                 [48.8534951, 2.3483915],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_f0dc2b48aaa91fa585dea1ffe19c85cb);
#
#
#         var popup_e10feb462ff94f4da1d33c776f74f40a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_952626358db6472db2a116f6c05a30ab = $(`&lt;div id=&quot;html_952626358db6472db2a116f6c05a30ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris: 15 titles.&lt;/div&gt;`)[0];
#                 popup_e10feb462ff94f4da1d33c776f74f40a.setContent(html_952626358db6472db2a116f6c05a30ab);
#
#
#
#         circle_78efd3fbf536e04dffe6963ee351821f.bindPopup(popup_e10feb462ff94f4da1d33c776f74f40a)
#         ;
#
#
#
#
#             var circle_9a7d8434f8d607ecd54138b13d169343 = L.circle(
#                 [53.866444, 10.684738],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_f0dc2b48aaa91fa585dea1ffe19c85cb);
#
#
#         var popup_a36e8396a19c308e0983191194b29022 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16836340e5248fe6c45b25b2b04cb3ac = $(`&lt;div id=&quot;html_16836340e5248fe6c45b25b2b04cb3ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lübeck: 2 titles.&lt;/div&gt;`)[0];
#                 popup_a36e8396a19c308e0983191194b29022.setContent(html_16836340e5248fe6c45b25b2b04cb3ac);
#
#
#
#         circle_9a7d8434f8d607ecd54138b13d169343.bindPopup(popup_a36e8396a19c308e0983191194b29022)
#         ;
#
#
#
#
#             var circle_8ec2741c33d041946a49107b45b05a3f = L.circle(
#                 [50.0012314, 8.2762513],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_f0dc2b48aaa91fa585dea1ffe19c85cb);
#
#
#         var popup_ae4ce29202875493963800b8ccca5917 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_112dc2f8b88027ef4949448ed3dd3b40 = $(`&lt;div id=&quot;html_112dc2f8b88027ef4949448ed3dd3b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mainz: 1 title.&lt;/div&gt;`)[0];
#                 popup_ae4ce29202875493963800b8ccca5917.setContent(html_112dc2f8b88027ef4949448ed3dd3b40);
#
#
#
#         circle_8ec2741c33d041946a49107b45b05a3f.bindPopup(popup_ae4ce29202875493963800b8ccca5917)
#         ;
#
#
#
#
#             var circle_9d4b36d912c830ebd7cd28a4983c10f1 = L.circle(
#                 [55.6867243, 12.5700724],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quo
# 1525-1550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8504900e9c086e7e6adbb2c7da9b0375 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8504900e9c086e7e6adbb2c7da9b0375&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8504900e9c086e7e6adbb2c7da9b0375 = L.map(
#                 &quot;map_8504900e9c086e7e6adbb2c7da9b0375&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94b580177a911e626a4d7bbf87f70066 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8504900e9c086e7e6adbb2c7da9b0375);
#
#
#             var circle_9c2cb580a61fca3af2c8fa5c5cc3c91f = L.circle(
#                 [48.8534951, 2.3483915],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8504900e9c086e7e6adbb2c7da9b0375);
#
#
#         var popup_39b02fd3f9d59b3b91aabec341c00a01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c502b8bb9b3804c1e22a517ce9da97b = $(`&lt;div id=&quot;html_8c502b8bb9b3804c1e22a517ce9da97b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris: 16 titles.&lt;/div&gt;`)[0];
#                 popup_39b02fd3f9d59b3b91aabec341c00a01.setContent(html_8c502b8bb9b3804c1e22a517ce9da97b);
#
#
#
#         circle_9c2cb580a61fca3af2c8fa5c5cc3c91f.bindPopup(popup_39b02fd3f9d59b3b91aabec341c00a01)
#         ;
#
#
#
#
#             var circle_5b4ce73519d20e89a17ff5d6cbb7a5e4 = L.circle(
#                 [50.938361, 6.959974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8504900e9c086e7e6adbb2c7da9b0375);
#
#
#         var popup_c7fe465d919750dab80cf62953d147d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3b2f0ef4d1bab79e349a30d925d4f38 = $(`&lt;div id=&quot;html_d3b2f0ef4d1bab79e349a30d925d4f38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Köln: 6 titles.&lt;/div&gt;`)[0];
#                 popup_c7fe465d919750dab80cf62953d147d9.setContent(html_d3b2f0ef4d1bab79e349a30d925d4f38);
#
#
#
#         circle_5b4ce73519d20e89a17ff5d6cbb7a5e4.bindPopup(popup_c7fe465d919750dab80cf62953d147d9)
#         ;
#
#
#
#
#             var circle_17003ddd7b615eb6277725ee426f8848 = L.circle(
#                 [52.3076216, -8.570897272891862],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8504900e9c086e7e6adbb2c7da9b0375);
#
#
#         var popup_f290132e1fc3a5384f5f86e5b1e0d718 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ddf67723bcf4859bec766208e76bc50 = $(`&lt;div id=&quot;html_6ddf67723bcf4859bec766208e76bc50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Münster: 3 titles.&lt;/div&gt;`)[0];
#                 popup_f290132e1fc3a5384f5f86e5b1e0d718.setContent(html_6ddf67723bcf4859bec766208e76bc50);
#
#
#
#         circle_17003ddd7b615eb6277725ee426f8848.bindPopup(popup_f290132e1fc3a5384f5f86e5b1e0d718)
#         ;
#
#
#
#
#             var circle_49e8ecf15f14047f03589776af01ac78 = L.circle(
#                 [53.866444, 10.684738],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;li
# 1550-1575
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ac710628d37e16e5bc92121cb709a7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ac710628d37e16e5bc92121cb709a7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ac710628d37e16e5bc92121cb709a7c = L.map(
#                 &quot;map_8ac710628d37e16e5bc92121cb709a7c&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7ee3a83192464b22cdc2f0221658c12 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ac710628d37e16e5bc92121cb709a7c);
#
#
#             var circle_7244c37425df8e6855c1d6f2de83ae9d = L.circle(
#                 [53.3670541, 7.2058304],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 307500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8ac710628d37e16e5bc92121cb709a7c);
#
#
#         var popup_3ad946a0ad9520731029c9e44e5e4164 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a70cf5b39c9ed718603b4bac1f592c7 = $(`&lt;div id=&quot;html_1a70cf5b39c9ed718603b4bac1f592c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Emden: 123 titles.&lt;/div&gt;`)[0];
#                 popup_3ad946a0ad9520731029c9e44e5e4164.setContent(html_1a70cf5b39c9ed718603b4bac1f592c7);
#
#
#
#         circle_7244c37425df8e6855c1d6f2de83ae9d.bindPopup(popup_3ad946a0ad9520731029c9e44e5e4164)
#         ;
#
#
#
#
#             var circle_d9f6724204acb5b4859f62c29e067611 = L.circle(
#                 [51.6576909, 6.617087],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 110000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8ac710628d37e16e5bc92121cb709a7c);
#
#
#         var popup_018e49ac638d204b2c00dbd2e3cf5968 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79e18706325ad5f845330ec93e541bb1 = $(`&lt;div id=&quot;html_79e18706325ad5f845330ec93e541bb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wesel: 44 titles.&lt;/div&gt;`)[0];
#                 popup_018e49ac638d204b2c00dbd2e3cf5968.setContent(html_79e18706325ad5f845330ec93e541bb1);
#
#
#
#         circle_d9f6724204acb5b4859f62c29e067611.bindPopup(popup_018e49ac638d204b2c00dbd2e3cf5968)
#         ;
#
#
#
#
#             var circle_0b9982f674f191b938176b616d1a354f = L.circle(
#                 [50.938361, 6.959974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8ac710628d37e16e5bc92121cb709a7c);
#
#
#         var popup_a8809e607adc3083fd7504bbb64e5b5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d27815f608c293b0a36d31f94cfe93b = $(`&lt;div id=&quot;html_9d27815f608c293b0a36d31f94cfe93b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Köln: 24 titles.&lt;/div&gt;`)[0];
#                 popup_a8809e607adc3083fd7504bbb64e5b5d.setContent(html_9d27815f608c293b0a36d31f94cfe93b);
#
#
#
#         circle_0b9982f674f191b938176b616d1a354f.bindPopup(popup_a8809e607adc3083fd7504bbb64e5b5d)
#         ;
#
#
#
#
#             var circle_10d2a28caf61e955bb1ae3621c12878c = L.circle(
#                 [51.4893335, -0.1440550845276872],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quo
# 1575-1600
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a494275e73f567d41e9f79a9ff0369c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a494275e73f567d41e9f79a9ff0369c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a494275e73f567d41e9f79a9ff0369c = L.map(
#                 &quot;map_0a494275e73f567d41e9f79a9ff0369c&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae5ad8484c5188e40299605caf6bd093 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a494275e73f567d41e9f79a9ff0369c);
#
#
#             var circle_de5af79551697dc3da9cfb08f3f78b23 = L.circle(
#                 [53.3670541, 7.2058304],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 345000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0a494275e73f567d41e9f79a9ff0369c);
#
#
#         var popup_37b21e6dc6e4a90e2fb654fb20a6129b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6a62b72748dc3a264efd54998a50a7c = $(`&lt;div id=&quot;html_e6a62b72748dc3a264efd54998a50a7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Emden: 138 titles.&lt;/div&gt;`)[0];
#                 popup_37b21e6dc6e4a90e2fb654fb20a6129b.setContent(html_e6a62b72748dc3a264efd54998a50a7c);
#
#
#
#         circle_de5af79551697dc3da9cfb08f3f78b23.bindPopup(popup_37b21e6dc6e4a90e2fb654fb20a6129b)
#         ;
#
#
#
#
#             var circle_1187c897ef5e9e4ebf78917c53d23e51 = L.circle(
#                 [51.6576909, 6.617087],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 112500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0a494275e73f567d41e9f79a9ff0369c);
#
#
#         var popup_5a115a30072ff7fd700a6ce2dde8b8e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac2f3fe92ccb09069c8faaf3b890c6b1 = $(`&lt;div id=&quot;html_ac2f3fe92ccb09069c8faaf3b890c6b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wesel: 45 titles.&lt;/div&gt;`)[0];
#                 popup_5a115a30072ff7fd700a6ce2dde8b8e6.setContent(html_ac2f3fe92ccb09069c8faaf3b890c6b1);
#
#
#
#         circle_1187c897ef5e9e4ebf78917c53d23e51.bindPopup(popup_5a115a30072ff7fd700a6ce2dde8b8e6)
#         ;
#
#
#
#
#             var circle_7a69993ad87feedb44dc2be74aeaddcc = L.circle(
#                 [50.938361, 6.959974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 107500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0a494275e73f567d41e9f79a9ff0369c);
#
#
#         var popup_7a698a530bca508ef98cde2c1cffc197 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52f61e557d9344512d28b26e19aa73e4 = $(`&lt;div id=&quot;html_52f61e557d9344512d28b26e19aa73e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Köln: 43 titles.&lt;/div&gt;`)[0];
#                 popup_7a698a530bca508ef98cde2c1cffc197.setContent(html_52f61e557d9344512d28b26e19aa73e4);
#
#
#
#         circle_7a69993ad87feedb44dc2be74aeaddcc.bindPopup(popup_7a698a530bca508ef98cde2c1cffc197)
#         ;
#
#
#
#
#             var circle_602ac7834b891489bc153db5384bef58 = L.circle(
#                 [51.4893335, -0.1440550845276872],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &qu

# %% [markdown]
# These maps can also be viewed in a separate window:
#
# * <a target="_new" href="_sources/map_europe_1450-1475.html">1450-1475</a>
# * <a target="_new" href="_sources/map_europe_1475-1500.html">1475-1500</a>
# * <a target="_new" href="_sources/map_europe_1500-1525.html">1500-1525</a>
# * <a target="_new" href="_sources/map_europe_1525-1550.html">1525-1550</a>
# * <a target="_new" href="_sources/map_europe_1550-1575.html">1550-1575</a>
# * <a target="_new" href="_sources/map_europe_1575-1600.html">1575-1600</a>
