# %% [markdown]
# # Analyses of places of publication

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from IPython.core.display import display, HTML
import pandas as pd
import numpy as np
import json
import re
from stcn import *
import folium
from tqdm import tqdm
from collections import Counter

# %% [markdown]
# ## Place of creation
#
# The following SPARQL query requests data about the titles published in the fifteenth or sixteenth century from the [Short Title Catalogue of the Netherlands](https://data.cerl.org/stcn/)

# %%
query = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX kb: <http://data.bibliotheken.nl/def#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT * WHERE {

# ?resource schema:mainEntityOfPage ?mainEntity .
# ?mainEntity schema:isPartOf <http://data.bibliotheken.nl/id/dataset/stcn>  . 
  
# ?resource schema:publication ?publ .
# ?resource schema:name ?title . 

OPTIONAL {
# ?resource schema:alternateName ?alt_title . }

OPTIONAL {
# ?publ schema:startDate ?publ_year . 
# ?publ schema:description ?imprint . 
# ?publ schema:publishedBy ?publisher . 
# ?publisher schema:name ?publ_name .
# ?publisher schema:location ?location_node .
# ?location_node schema:address ?address .
# ?address schema:addressLocality ?place . 
} .

FILTER( regex(?publ_year, "^1[45]", "i") ) .

} 

"""
df = run_query(query)

# %%
nr_results = df.drop_duplicates(subset=['resource.value']).shape[0]
print(f'The query returns information about {nr_results} titles.')
# Out:
# The query returns information about 8332 titles.

# %% [markdown]
# In some records, the year of publication is truncated. The cell below replaces the truncated values to the number '5', to make it easier to process those values.

# %%
def standardise_date(row):
    if re.search(r'x' , row['publ_year.value'] , re.IGNORECASE):
        row['publ_year.value'] = re.sub( 'x' , '5' , row['publ_year.value'] , re.IGNORECASE)
    
    if re.search(r'\d{4}' , row['publ_year.value']):
        return int(row['publ_year.value'])
    else:
        return np.nan
    
    
df['datetime'] = df.apply(standardise_date, axis=1)
df=df.dropna(subset=['datetime'])

# %% [markdown]
# The file {Download}`stcn_gis.tsv<stcn_gis.tsv>` contains an list of all the cities that are mentioned in the STCN. Additionally, it contains the latitude and the longitude of these locations, and information about the countries these cities are in. The assignment of the country is based on today's political borders. The information was created via [geocoding](https://developers.arcgis.com/documentation/mapping-apis-and-services/geocoding/).
#
#
# The file 'stcn_gis.tsv' is read using the code below.

# %%
locations = pd.read_csv('stcn_gis.tsv',sep='\t')

gis = dict()
country = dict()

for i,row in locations.iterrows():
    gis[row['name']] = [row['latitude'],row['longitude']]
    if re.search( r',' ,row['display_name'] ):
        parts = re.split( r',' , row['display_name'] )
        country_name = parts[-1].strip()
    else:
        country_name = row['display_name']
    if re.search(r'\/', country_name ):
        country_name = country_name[ country_name.rindex('/')+1:]
    country[ row['name'] ] = country_name.strip()

# %% [markdown]
# The following code converts the STCN data to the JSON format, to ease the processing of these data. The place names are also enriched with the geographic coordinates. Running the cell may take time. The data set is written to the disk under the file name 'stcn_locations.js'.

# %%
unique_ids = df.sort_values('datetime')['resource.value'].unique()

data = []

def print_value(value):
    if pd.isna(value):
        return ''
    else:
        return value
    
def get_values(df,field,fields_dict):
    rows = df.drop_duplicates(field)
    all_rows = []
    for i,row in rows.iterrows():
        values = dict()
        for f in fields_dict:
            values[fields_dict[f]] = print_value(row[f])
        all_rows.append(values)
    return all_rows    


for resource in tqdm(unique_ids):

    record = dict()
    record['ppn'] = resource
    #print(resource)

    df_resource = df[ df['resource.value'] == resource ]
    
    record['title'] = df_resource.iloc[0]['title.value']
    if not pd.isna(df_resource.iloc[0]['alt_title.value']):
        record['alternative_title'] = df_resource.iloc[0]['alt_title.value']
    record['year'] = df_resource.iloc[0]['publ_year.value']
    
    ## Publishers
    unique_id = 'publisher.value'
    fields_dict = { 'publisher.value':'ppn',
        'publ_name.value':'name' ,
        'place.value':'place' , 
        
    }
    
    all_publishers = get_values(df_resource,unique_id,fields_dict)
    record['publishers'] = all_publishers
    
    place = df_resource.iloc[0]['place.value']
    coordinates = gis.get(place)

    if coordinates:
        record['location'] = { 
            'place_name' : place , 
            'latitude':coordinates[0] , 
                             'longitude':coordinates[1] , 
                             'country':country.get(place)}

    data.append(record)
    
with open('stcn_locations.json','w',encoding='utf-8') as out:
    out.write(json.dumps(data,indent=4))
    
f = open('stcn_locations.json')
json_data = json.load(f)
f.close()
# Out:
# 100%|██████████████████████████████████████| 6442/6442 [00:11<00:00, 545.01it/s]

# %%
def singular_plural(noun,count):
    if count>1:
        noun=noun+'s'
    return noun
        
def print_map_nl(place_count,out_file='map.html'):
    
    map = folium.Map( location=[51.875127716984274, 5.360011275145361] , 
    width="%100",
    height="%100",
    zoom_start=8)

    for place,count in place_count.most_common():

        folium.Circle(
            location=[ gis[place][0], gis[place][1]],
            radius= count * 25 ,
            color='#1827c9',
            fill=False ,
            fill_opacity = 0.5,
            fill_color = '#c72d22' ,
            weight = 2 ,
            popup = f'{place}: {count} {singular_plural("title",count)}.').add_to(map)

    map.save(out_file)
    return map
 
def print_map_world(place_count,out_file='map.html'):
    map = folium.Map( location=[52.157004081232024, 4.495349166689632] , 
    width="%100",
    height="%100",
    zoom_start=3)

    for place,count in place_count.most_common():

        folium.Circle(
            location=[ gis[place][0], gis[place][1]],
            radius= count*500 ,
            color='#1827c9',
            fill=False ,
            fill_opacity = 0.5,
            fill_color = '#c72d22' ,
            weight = 2 ,
            popup = f'{place}: {count} {singular_plural("title",count)}.').add_to(map)

    map.save(out_file)
    return map

# %% [markdown]
# How did the art of printing spread across the low countries? The code below identifies the cities that are mentioned in the export from the STCN. The analyses is broken down by periods of 25 years.

# %%
cities = []
from IPython.display import display

period_length = 25

for year in range( 1450 , 1600, period_length ):
    end = year+period_length
    out_file= f'map_{year}-{end}.html'
    
    print(f'\n{year}-{end}\n\n')
    
    for title in json_data:
        title['year'] = re.sub(r'X','5',title['year'],re.IGNORECASE)
        if 'location' in title:
            if int(title['year']) >= year and int(title['year'])<end and (title['location']['country'] == 'Nederland' or title['location']['country'] == 'Belgien'):
                cities.append(title['location']['place_name'])
                #print(title['location']['place_name'])

    place_count = Counter(cities)
    folium_map = print_map_nl(place_count,out_file= out_file)
    display(folium_map)
# Out:
# 1450-1475
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ca7379c017418918e850d0b037d4062 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ca7379c017418918e850d0b037d4062&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ca7379c017418918e850d0b037d4062 = L.map(
#                 &quot;map_1ca7379c017418918e850d0b037d4062&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63e43521825473cf2a7101b88eea4fcb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1ca7379c017418918e850d0b037d4062);
#
#
#             var circle_430de87855482b10c2ffb54d3ff0625c = L.circle(
#                 [52.0907006, 5.1215634],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 450, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_1ca7379c017418918e850d0b037d4062);
#
#
#         var popup_de69ced2f724d68ba1f1742509a5d380 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f6c2d3417fb6a5da354cb8d9b27070a = $(`&lt;div id=&quot;html_3f6c2d3417fb6a5da354cb8d9b27070a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Utrecht: 18 titles.&lt;/div&gt;`)[0];
#                 popup_de69ced2f724d68ba1f1742509a5d380.setContent(html_3f6c2d3417fb6a5da354cb8d9b27070a);
#
#
#
#         circle_430de87855482b10c2ffb54d3ff0625c.bindPopup(popup_de69ced2f724d68ba1f1742509a5d380)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# 1475-1500
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37447b28be1114f4295e66e13d750363 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37447b28be1114f4295e66e13d750363&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37447b28be1114f4295e66e13d750363 = L.map(
#                 &quot;map_37447b28be1114f4295e66e13d750363&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdcde130e0c7ca604f809d3308a73286 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37447b28be1114f4295e66e13d750363);
#
#
#             var circle_3f1a1d0ddc94cdc074db2a6266a709c4 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7300, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_37447b28be1114f4295e66e13d750363);
#
#
#         var popup_f66096e002261fbb7226b8606d358259 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bac6f624b88057cc517d0fea136fc128 = $(`&lt;div id=&quot;html_bac6f624b88057cc517d0fea136fc128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 292 titles.&lt;/div&gt;`)[0];
#                 popup_f66096e002261fbb7226b8606d358259.setContent(html_bac6f624b88057cc517d0fea136fc128);
#
#
#
#         circle_3f1a1d0ddc94cdc074db2a6266a709c4.bindPopup(popup_f66096e002261fbb7226b8606d358259)
#         ;
#
#
#
#
#             var circle_cdbfbdfbbef6d94cce90527048f63b1d = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2575, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_37447b28be1114f4295e66e13d750363);
#
#
#         var popup_bbaf81338fe0b92dfb11695fb4ca2c23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29af34440f5d3eb47659f8c172f31483 = $(`&lt;div id=&quot;html_29af34440f5d3eb47659f8c172f31483&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 103 titles.&lt;/div&gt;`)[0];
#                 popup_bbaf81338fe0b92dfb11695fb4ca2c23.setContent(html_29af34440f5d3eb47659f8c172f31483);
#
#
#
#         circle_cdbfbdfbbef6d94cce90527048f63b1d.bindPopup(popup_bbaf81338fe0b92dfb11695fb4ca2c23)
#         ;
#
#
#
#
#             var circle_2a381598abe4b49eed33c437c88d1bc2 = L.circle(
#                 [52.0114922, 4.7106094],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_37447b28be1114f4295e66e13d750363);
#
#
#         var popup_d4430f59a5b2aa9e53b649b4e6681010 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f87f799308e06838f18f8f8c172ded13 = $(`&lt;div id=&quot;html_f87f799308e06838f18f8f8c172ded13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gouda: 72 titles.&lt;/div&gt;`)[0];
#                 popup_d4430f59a5b2aa9e53b649b4e6681010.setContent(html_f87f799308e06838f18f8f8c172ded13);
#
#
#
#         circle_2a381598abe4b49eed33c437c88d1bc2.bindPopup(popup_d4430f59a5b2aa9e53b649b4e6681010)
#         ;
#
#
#
#
#             var circle_d483b024a9dbd3c20b01b4db716117a6 = L.circle(
#                 [52.5089759, 6.0943765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quo
# 1500-1525
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65c6b665659d00f4656d6148bd4d28fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65c6b665659d00f4656d6148bd4d28fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65c6b665659d00f4656d6148bd4d28fc = L.map(
#                 &quot;map_65c6b665659d00f4656d6148bd4d28fc&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1f56f7bedd2aa4e48dd27a7e3d7af47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_65c6b665659d00f4656d6148bd4d28fc);
#
#
#             var circle_169b66e2a43f35e6f2f6b09492b6d049 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21050, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_65c6b665659d00f4656d6148bd4d28fc);
#
#
#         var popup_55be730a94cee3d6a915529c65403b68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40c86554e524544b171ae9055aadfe63 = $(`&lt;div id=&quot;html_40c86554e524544b171ae9055aadfe63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 842 titles.&lt;/div&gt;`)[0];
#                 popup_55be730a94cee3d6a915529c65403b68.setContent(html_40c86554e524544b171ae9055aadfe63);
#
#
#
#         circle_169b66e2a43f35e6f2f6b09492b6d049.bindPopup(popup_55be730a94cee3d6a915529c65403b68)
#         ;
#
#
#
#
#             var circle_b06e1fd183ab00003f4f618eb5fb50fb = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2900, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_65c6b665659d00f4656d6148bd4d28fc);
#
#
#         var popup_5881c714808501d3ac33ad6d710d4686 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6814e1213b2d29e06cbb7b7761f76c31 = $(`&lt;div id=&quot;html_6814e1213b2d29e06cbb7b7761f76c31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 116 titles.&lt;/div&gt;`)[0];
#                 popup_5881c714808501d3ac33ad6d710d4686.setContent(html_6814e1213b2d29e06cbb7b7761f76c31);
#
#
#
#         circle_b06e1fd183ab00003f4f618eb5fb50fb.bindPopup(popup_5881c714808501d3ac33ad6d710d4686)
#         ;
#
#
#
#
#             var circle_11f50b1b01ff59375eb2c3c57c3c2f07 = L.circle(
#                 [52.5089759, 6.0943765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2575, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_65c6b665659d00f4656d6148bd4d28fc);
#
#
#         var popup_77cb443e217835ec869b92c39ece7fb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e28dac256fd9c73efab1c3901e9d307 = $(`&lt;div id=&quot;html_5e28dac256fd9c73efab1c3901e9d307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zwolle: 103 titles.&lt;/div&gt;`)[0];
#                 popup_77cb443e217835ec869b92c39ece7fb7.setContent(html_5e28dac256fd9c73efab1c3901e9d307);
#
#
#
#         circle_11f50b1b01ff59375eb2c3c57c3c2f07.bindPopup(popup_77cb443e217835ec869b92c39ece7fb7)
#         ;
#
#
#
#
#             var circle_ce74157f822d4e07a01873a52176c9c6 = L.circle(
#                 [52.0114922, 4.7106094],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&
# 1525-1550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c56cf23dfbaa8951f380e49f9cc23638 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c56cf23dfbaa8951f380e49f9cc23638&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c56cf23dfbaa8951f380e49f9cc23638 = L.map(
#                 &quot;map_c56cf23dfbaa8951f380e49f9cc23638&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3a8332e2a4707936c70fa183775783f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c56cf23dfbaa8951f380e49f9cc23638);
#
#
#             var circle_ed10a7593592ab3ef8bc844c9c642cb4 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22575, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c56cf23dfbaa8951f380e49f9cc23638);
#
#
#         var popup_f400ce85a1baf1402aa9355027118938 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c922d6b3e7fae90056b4096ef0818ea1 = $(`&lt;div id=&quot;html_c922d6b3e7fae90056b4096ef0818ea1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 903 titles.&lt;/div&gt;`)[0];
#                 popup_f400ce85a1baf1402aa9355027118938.setContent(html_c922d6b3e7fae90056b4096ef0818ea1);
#
#
#
#         circle_ed10a7593592ab3ef8bc844c9c642cb4.bindPopup(popup_f400ce85a1baf1402aa9355027118938)
#         ;
#
#
#
#
#             var circle_54fc46b7a1f18ae555bbc300d90641c4 = L.circle(
#                 [51.2211097, 4.3997081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4225, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c56cf23dfbaa8951f380e49f9cc23638);
#
#
#         var popup_1790e152c675ed8f1b6a234d4095cd63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7571f62ad5b0e72a68b7b9b4f2f1fa81 = $(`&lt;div id=&quot;html_7571f62ad5b0e72a68b7b9b4f2f1fa81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Antwerpen: 169 titles.&lt;/div&gt;`)[0];
#                 popup_1790e152c675ed8f1b6a234d4095cd63.setContent(html_7571f62ad5b0e72a68b7b9b4f2f1fa81);
#
#
#
#         circle_54fc46b7a1f18ae555bbc300d90641c4.bindPopup(popup_1790e152c675ed8f1b6a234d4095cd63)
#         ;
#
#
#
#
#             var circle_af367ceba90bd928dc70c26bb31e6092 = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3275, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c56cf23dfbaa8951f380e49f9cc23638);
#
#
#         var popup_03355d58abf58aacff38025a6bdd5919 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ebcb73c89b5977edcca1b6baff63652 = $(`&lt;div id=&quot;html_2ebcb73c89b5977edcca1b6baff63652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 131 titles.&lt;/div&gt;`)[0];
#                 popup_03355d58abf58aacff38025a6bdd5919.setContent(html_2ebcb73c89b5977edcca1b6baff63652);
#
#
#
#         circle_af367ceba90bd928dc70c26bb31e6092.bindPopup(popup_03355d58abf58aacff38025a6bdd5919)
#         ;
#
#
#
#
#             var circle_b8d876367326a13cfa5904e1cdeca7bf = L.circle(
#                 [52.1518157, 4.4811088666204295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &q
# 1550-1575
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_865cefa1d3368efb0fe3e2af681ea417 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_865cefa1d3368efb0fe3e2af681ea417&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_865cefa1d3368efb0fe3e2af681ea417 = L.map(
#                 &quot;map_865cefa1d3368efb0fe3e2af681ea417&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acfa2d51007f63250fb866aa2a0efb00 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_865cefa1d3368efb0fe3e2af681ea417);
#
#
#             var circle_98ee1257fdfdbf4d5a4d26bb1ccfdbe4 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23100, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_865cefa1d3368efb0fe3e2af681ea417);
#
#
#         var popup_127cb4b923f0eb7f55291c1da37c5278 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26fa70d3d94732429fa8cc9f854b0383 = $(`&lt;div id=&quot;html_26fa70d3d94732429fa8cc9f854b0383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 924 titles.&lt;/div&gt;`)[0];
#                 popup_127cb4b923f0eb7f55291c1da37c5278.setContent(html_26fa70d3d94732429fa8cc9f854b0383);
#
#
#
#         circle_98ee1257fdfdbf4d5a4d26bb1ccfdbe4.bindPopup(popup_127cb4b923f0eb7f55291c1da37c5278)
#         ;
#
#
#
#
#             var circle_344f2d76e7261b9a018272a33dd7e8b2 = L.circle(
#                 [51.2211097, 4.3997081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8700, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_865cefa1d3368efb0fe3e2af681ea417);
#
#
#         var popup_89836b130e0b2502911da7d8a9a264a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbec90de41452fe3f37cf49278d0a60b = $(`&lt;div id=&quot;html_fbec90de41452fe3f37cf49278d0a60b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Antwerpen: 348 titles.&lt;/div&gt;`)[0];
#                 popup_89836b130e0b2502911da7d8a9a264a6.setContent(html_fbec90de41452fe3f37cf49278d0a60b);
#
#
#
#         circle_344f2d76e7261b9a018272a33dd7e8b2.bindPopup(popup_89836b130e0b2502911da7d8a9a264a6)
#         ;
#
#
#
#
#             var circle_b3fc7d073dc596144a637903b739b840 = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4800, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_865cefa1d3368efb0fe3e2af681ea417);
#
#
#         var popup_a100c92a86f65d0119a9edb3b832fcab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88bdb4257b73b9dd58905ffaf888cf54 = $(`&lt;div id=&quot;html_88bdb4257b73b9dd58905ffaf888cf54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 192 titles.&lt;/div&gt;`)[0];
#                 popup_a100c92a86f65d0119a9edb3b832fcab.setContent(html_88bdb4257b73b9dd58905ffaf888cf54);
#
#
#
#         circle_b3fc7d073dc596144a637903b739b840.bindPopup(popup_a100c92a86f65d0119a9edb3b832fcab)
#         ;
#
#
#
#
#             var circle_ce4e99bebf8e01610bada9d2657672cd = L.circle(
#                 [52.1518157, 4.4811088666204295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &q
# 1575-1600
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce94f11acfa039cf7cd007deaad45737 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce94f11acfa039cf7cd007deaad45737&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce94f11acfa039cf7cd007deaad45737 = L.map(
#                 &quot;map_ce94f11acfa039cf7cd007deaad45737&quot;,
#                 {
#                     center: [51.875127716984274, 5.360011275145361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9369414995b3c4f92cc7ce7a0740a62a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce94f11acfa039cf7cd007deaad45737);
#
#
#             var circle_611f2adca497708a11ff367792d32bb5 = L.circle(
#                 [52.1518157, 4.4811088666204295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 36675, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ce94f11acfa039cf7cd007deaad45737);
#
#
#         var popup_347d2ba964a9dc43b0ee16d250aab742 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6dae881300cb9f07f1574c0eaa508efd = $(`&lt;div id=&quot;html_6dae881300cb9f07f1574c0eaa508efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Leiden: 1467 titles.&lt;/div&gt;`)[0];
#                 popup_347d2ba964a9dc43b0ee16d250aab742.setContent(html_6dae881300cb9f07f1574c0eaa508efd);
#
#
#
#         circle_611f2adca497708a11ff367792d32bb5.bindPopup(popup_347d2ba964a9dc43b0ee16d250aab742)
#         ;
#
#
#
#
#             var circle_e03c8c6196f05ec23bc0366c3f0591c4 = L.circle(
#                 [52.2695736, 6.236339604766698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23825, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ce94f11acfa039cf7cd007deaad45737);
#
#
#         var popup_6de6a59a35ac969c22fae46871710a03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76ee34b6137396baa2e32bef7d5e101a = $(`&lt;div id=&quot;html_76ee34b6137396baa2e32bef7d5e101a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Deventer: 953 titles.&lt;/div&gt;`)[0];
#                 popup_6de6a59a35ac969c22fae46871710a03.setContent(html_76ee34b6137396baa2e32bef7d5e101a);
#
#
#
#         circle_e03c8c6196f05ec23bc0366c3f0591c4.bindPopup(popup_6de6a59a35ac969c22fae46871710a03)
#         ;
#
#
#
#
#             var circle_9e677a1d7d44b4f17c770e962d144ead = L.circle(
#                 [51.9994572, 4.362724538543995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14125, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ce94f11acfa039cf7cd007deaad45737);
#
#
#         var popup_03fb60fb8fe22f30e1f8f83449b83d10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1497d48f5fdf74d2834ee56f07e7fbea = $(`&lt;div id=&quot;html_1497d48f5fdf74d2834ee56f07e7fbea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delft: 565 titles.&lt;/div&gt;`)[0];
#                 popup_03fb60fb8fe22f30e1f8f83449b83d10.setContent(html_1497d48f5fdf74d2834ee56f07e7fbea);
#
#
#
#         circle_9e677a1d7d44b4f17c770e962d144ead.bindPopup(popup_03fb60fb8fe22f30e1f8f83449b83d10)
#         ;
#
#
#
#
#             var circle_33b0b20052a2c856c811ce35a799aa40 = L.circle(
#                 [51.2211097, 4.3997081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &q

# %% [markdown]
# These maps can also be viewed in a separate window:
#
# * {Download}`1450-1475<map_1450-1475.html>`
# * {Download}`1475-1500<map_1475-1500.html>`
# * {Download}`1500-1525<map_1500-1525.html>`
# * {Download}`1525-1550<map_1525-1550.html>`
# * {Download}`1550-1575<map_1550-1575.html>`
# * {Download}`1575-1600<map_1575-1600.html>`

# %% [markdown]
# ## Printing in Dutch outside of the Low Countries

# %%
cities = []

period_length = 25

for year in range( 1450 , 1600, period_length ):
    end = year+period_length
    print(f'{year}-{end}')
    
    for title in json_data:
        title['year'] = re.sub(r'X','5',title['year'],re.IGNORECASE)
        if 'location' in title:
            if int(title['year']) >= year and int(title['year'])<end and title['location']['country'] != 'Nederland' and title['location']['country'] != 'Belgien':
                if title['location']['place_name'] != 'Place unknown':
                    cities.append(title['location']['place_name'])
                #print(title['location']['place_name'])

    place_count = Counter(cities)


    folium_map = print_map_world(place_count,out_file= f'map_europe_{year}-{end}.html')
    display(folium_map)
# Out:
# 1450-1475
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33e1aeb44f813421811f6b8c2ea46a19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33e1aeb44f813421811f6b8c2ea46a19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33e1aeb44f813421811f6b8c2ea46a19 = L.map(
#                 &quot;map_33e1aeb44f813421811f6b8c2ea46a19&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccbee32ede80fac036afb46a86aab472 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_33e1aeb44f813421811f6b8c2ea46a19);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# 1475-1500
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aff888f62f39109cb600f1922202a42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aff888f62f39109cb600f1922202a42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8aff888f62f39109cb600f1922202a42 = L.map(
#                 &quot;map_8aff888f62f39109cb600f1922202a42&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a29b3efa0e0e6a890bae42390c9288d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8aff888f62f39109cb600f1922202a42);
#
#
#             var circle_39372d924833f2c4381359a309f711a0 = L.circle(
#                 [50.0012314, 8.2762513],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8aff888f62f39109cb600f1922202a42);
#
#
#         var popup_222e4adda4ca6c3e0aca5073d4fc0dac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6ff919813bf64e75f7aa4d7ae314966 = $(`&lt;div id=&quot;html_e6ff919813bf64e75f7aa4d7ae314966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mainz: 1 title.&lt;/div&gt;`)[0];
#                 popup_222e4adda4ca6c3e0aca5073d4fc0dac.setContent(html_e6ff919813bf64e75f7aa4d7ae314966);
#
#
#
#         circle_39372d924833f2c4381359a309f711a0.bindPopup(popup_222e4adda4ca6c3e0aca5073d4fc0dac)
#         ;
#
#
#
#
#             var circle_c4fcd970f4c1fb144f21593277712a44 = L.circle(
#                 [53.866444, 10.684738],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8aff888f62f39109cb600f1922202a42);
#
#
#         var popup_3abd5325cbeed6bea20e30c4df48b47a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27e6669f6ada1a8857744960e2570202 = $(`&lt;div id=&quot;html_27e6669f6ada1a8857744960e2570202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lübeck: 1 title.&lt;/div&gt;`)[0];
#                 popup_3abd5325cbeed6bea20e30c4df48b47a.setContent(html_27e6669f6ada1a8857744960e2570202);
#
#
#
#         circle_c4fcd970f4c1fb144f21593277712a44.bindPopup(popup_3abd5325cbeed6bea20e30c4df48b47a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# 1500-1525
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19eea6c87ae4a2b161fd0a2f65b86e47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19eea6c87ae4a2b161fd0a2f65b86e47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19eea6c87ae4a2b161fd0a2f65b86e47 = L.map(
#                 &quot;map_19eea6c87ae4a2b161fd0a2f65b86e47&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4537b52941afce49110b1f55cef60c2d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19eea6c87ae4a2b161fd0a2f65b86e47);
#
#
#             var circle_9b956ef2957047b23b939aa979253a6d = L.circle(
#                 [48.8534951, 2.3483915],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_19eea6c87ae4a2b161fd0a2f65b86e47);
#
#
#         var popup_63fda58426baab024d67072370f4e938 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd23e45b77a806b7ec6367a07abc5bba = $(`&lt;div id=&quot;html_cd23e45b77a806b7ec6367a07abc5bba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris: 15 titles.&lt;/div&gt;`)[0];
#                 popup_63fda58426baab024d67072370f4e938.setContent(html_cd23e45b77a806b7ec6367a07abc5bba);
#
#
#
#         circle_9b956ef2957047b23b939aa979253a6d.bindPopup(popup_63fda58426baab024d67072370f4e938)
#         ;
#
#
#
#
#             var circle_77b92d4432eb4edf645fb1ee34f32b36 = L.circle(
#                 [53.866444, 10.684738],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_19eea6c87ae4a2b161fd0a2f65b86e47);
#
#
#         var popup_6d56560a64b4bae784e45a90940823ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e38eb881a3dee447b79a2383dc71e0ab = $(`&lt;div id=&quot;html_e38eb881a3dee447b79a2383dc71e0ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lübeck: 2 titles.&lt;/div&gt;`)[0];
#                 popup_6d56560a64b4bae784e45a90940823ae.setContent(html_e38eb881a3dee447b79a2383dc71e0ab);
#
#
#
#         circle_77b92d4432eb4edf645fb1ee34f32b36.bindPopup(popup_6d56560a64b4bae784e45a90940823ae)
#         ;
#
#
#
#
#             var circle_158fe885bb36cb92be06e104701915f6 = L.circle(
#                 [50.0012314, 8.2762513],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_19eea6c87ae4a2b161fd0a2f65b86e47);
#
#
#         var popup_d1495a29c850bfaadabb757738dd745a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c6c3fc1f3aef309b99532922bf3a9bf = $(`&lt;div id=&quot;html_5c6c3fc1f3aef309b99532922bf3a9bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mainz: 1 title.&lt;/div&gt;`)[0];
#                 popup_d1495a29c850bfaadabb757738dd745a.setContent(html_5c6c3fc1f3aef309b99532922bf3a9bf);
#
#
#
#         circle_158fe885bb36cb92be06e104701915f6.bindPopup(popup_d1495a29c850bfaadabb757738dd745a)
#         ;
#
#
#
#
#             var circle_c2e04cdf25801fa2895acccc2bc68ce1 = L.circle(
#                 [55.6867243, 12.5700724],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;
# 1525-1550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed2f64c974f51f804ddaaf085e232475 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed2f64c974f51f804ddaaf085e232475&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed2f64c974f51f804ddaaf085e232475 = L.map(
#                 &quot;map_ed2f64c974f51f804ddaaf085e232475&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69f0e4789bec4508b7d91fdf574ee52b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed2f64c974f51f804ddaaf085e232475);
#
#
#             var circle_02d7a2380bcd3f3e967bd4d5e57f6f76 = L.circle(
#                 [48.8534951, 2.3483915],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ed2f64c974f51f804ddaaf085e232475);
#
#
#         var popup_8c8e2d091d138dc468b18baaa4383e1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5948fd16c1b80a6093bc2ee2908864d5 = $(`&lt;div id=&quot;html_5948fd16c1b80a6093bc2ee2908864d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris: 16 titles.&lt;/div&gt;`)[0];
#                 popup_8c8e2d091d138dc468b18baaa4383e1d.setContent(html_5948fd16c1b80a6093bc2ee2908864d5);
#
#
#
#         circle_02d7a2380bcd3f3e967bd4d5e57f6f76.bindPopup(popup_8c8e2d091d138dc468b18baaa4383e1d)
#         ;
#
#
#
#
#             var circle_87a09276b9f1ca6092deae62f56126e7 = L.circle(
#                 [50.938361, 6.959974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ed2f64c974f51f804ddaaf085e232475);
#
#
#         var popup_9844ab440f62cb7992e7618b945fdaae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_610993de53a129cfffb90275586737c3 = $(`&lt;div id=&quot;html_610993de53a129cfffb90275586737c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Köln: 6 titles.&lt;/div&gt;`)[0];
#                 popup_9844ab440f62cb7992e7618b945fdaae.setContent(html_610993de53a129cfffb90275586737c3);
#
#
#
#         circle_87a09276b9f1ca6092deae62f56126e7.bindPopup(popup_9844ab440f62cb7992e7618b945fdaae)
#         ;
#
#
#
#
#             var circle_63a53020e116e08204168f89b454b9ca = L.circle(
#                 [52.3076216, -8.570897272891862],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ed2f64c974f51f804ddaaf085e232475);
#
#
#         var popup_29845b027d229a5ae8e6528d9aab5e7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bca34e5697506487517ce739799ed53d = $(`&lt;div id=&quot;html_bca34e5697506487517ce739799ed53d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Münster: 3 titles.&lt;/div&gt;`)[0];
#                 popup_29845b027d229a5ae8e6528d9aab5e7d.setContent(html_bca34e5697506487517ce739799ed53d);
#
#
#
#         circle_63a53020e116e08204168f89b454b9ca.bindPopup(popup_29845b027d229a5ae8e6528d9aab5e7d)
#         ;
#
#
#
#
#             var circle_ca984d7816b34dcf9f30dc65eb481dcf = L.circle(
#                 [53.866444, 10.684738],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;line
# 1550-1575
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a059a7161f2ac6df1ce4ee1c982ceba7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a059a7161f2ac6df1ce4ee1c982ceba7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a059a7161f2ac6df1ce4ee1c982ceba7 = L.map(
#                 &quot;map_a059a7161f2ac6df1ce4ee1c982ceba7&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fda29e71ac9775aeacee71e4e98c1da = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a059a7161f2ac6df1ce4ee1c982ceba7);
#
#
#             var circle_a833587380250821aa787fc440d143f3 = L.circle(
#                 [53.3670541, 7.2058304],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 61500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a059a7161f2ac6df1ce4ee1c982ceba7);
#
#
#         var popup_4435046b71f55d311262dde723c9e34b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2eaa636022a4b30e3c2db6a88204237a = $(`&lt;div id=&quot;html_2eaa636022a4b30e3c2db6a88204237a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Emden: 123 titles.&lt;/div&gt;`)[0];
#                 popup_4435046b71f55d311262dde723c9e34b.setContent(html_2eaa636022a4b30e3c2db6a88204237a);
#
#
#
#         circle_a833587380250821aa787fc440d143f3.bindPopup(popup_4435046b71f55d311262dde723c9e34b)
#         ;
#
#
#
#
#             var circle_d5da88f1d9c7972903c2d33177f9464f = L.circle(
#                 [51.6576909, 6.617087],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a059a7161f2ac6df1ce4ee1c982ceba7);
#
#
#         var popup_566a5f82499af7ed5d3fab78bfc3e61a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74949e6b45c126030fceb02cd092ed25 = $(`&lt;div id=&quot;html_74949e6b45c126030fceb02cd092ed25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wesel: 44 titles.&lt;/div&gt;`)[0];
#                 popup_566a5f82499af7ed5d3fab78bfc3e61a.setContent(html_74949e6b45c126030fceb02cd092ed25);
#
#
#
#         circle_d5da88f1d9c7972903c2d33177f9464f.bindPopup(popup_566a5f82499af7ed5d3fab78bfc3e61a)
#         ;
#
#
#
#
#             var circle_45babe06c51301beea9a5c5713d5e213 = L.circle(
#                 [50.938361, 6.959974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a059a7161f2ac6df1ce4ee1c982ceba7);
#
#
#         var popup_2a7fc749e5549e1fc541397e5766708a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6df0288c5cb7e7b31fe92bd35a2248a8 = $(`&lt;div id=&quot;html_6df0288c5cb7e7b31fe92bd35a2248a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Köln: 24 titles.&lt;/div&gt;`)[0];
#                 popup_2a7fc749e5549e1fc541397e5766708a.setContent(html_6df0288c5cb7e7b31fe92bd35a2248a8);
#
#
#
#         circle_45babe06c51301beea9a5c5713d5e213.bindPopup(popup_2a7fc749e5549e1fc541397e5766708a)
#         ;
#
#
#
#
#             var circle_67ae39f6393cfcb2bce8aec4b3962a04 = L.circle(
#                 [51.4893335, -0.1440550845276872],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;
# 1575-1600
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_747593059fedc647556987ac6c1780f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_747593059fedc647556987ac6c1780f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_747593059fedc647556987ac6c1780f8 = L.map(
#                 &quot;map_747593059fedc647556987ac6c1780f8&quot;,
#                 {
#                     center: [52.157004081232024, 4.495349166689632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09ca5ec478abbc414ab1204dfc03db1a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_747593059fedc647556987ac6c1780f8);
#
#
#             var circle_04e4b8344136c9e0caab86d9030e6b30 = L.circle(
#                 [53.3670541, 7.2058304],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 69000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_747593059fedc647556987ac6c1780f8);
#
#
#         var popup_e51636ebb651507c38f6812af04dcafe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1ecd1766f531023dd7a8c9c121f30dd = $(`&lt;div id=&quot;html_a1ecd1766f531023dd7a8c9c121f30dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Emden: 138 titles.&lt;/div&gt;`)[0];
#                 popup_e51636ebb651507c38f6812af04dcafe.setContent(html_a1ecd1766f531023dd7a8c9c121f30dd);
#
#
#
#         circle_04e4b8344136c9e0caab86d9030e6b30.bindPopup(popup_e51636ebb651507c38f6812af04dcafe)
#         ;
#
#
#
#
#             var circle_c0cea9e2fe78daf39aae802a5e37e46f = L.circle(
#                 [51.6576909, 6.617087],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_747593059fedc647556987ac6c1780f8);
#
#
#         var popup_6a4b4d86aa5924b938712cc03213dd09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc251bf4f27cbb431eca463db1ef6fd9 = $(`&lt;div id=&quot;html_cc251bf4f27cbb431eca463db1ef6fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wesel: 45 titles.&lt;/div&gt;`)[0];
#                 popup_6a4b4d86aa5924b938712cc03213dd09.setContent(html_cc251bf4f27cbb431eca463db1ef6fd9);
#
#
#
#         circle_c0cea9e2fe78daf39aae802a5e37e46f.bindPopup(popup_6a4b4d86aa5924b938712cc03213dd09)
#         ;
#
#
#
#
#             var circle_2d48e15c1c4cd91127509ad94110970f = L.circle(
#                 [50.938361, 6.959974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_747593059fedc647556987ac6c1780f8);
#
#
#         var popup_b3f4286e3b4dc88d1574d184361ed0b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c2a7682bab00a3b02a106390471deff = $(`&lt;div id=&quot;html_6c2a7682bab00a3b02a106390471deff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Köln: 43 titles.&lt;/div&gt;`)[0];
#                 popup_b3f4286e3b4dc88d1574d184361ed0b6.setContent(html_6c2a7682bab00a3b02a106390471deff);
#
#
#
#         circle_2d48e15c1c4cd91127509ad94110970f.bindPopup(popup_b3f4286e3b4dc88d1574d184361ed0b6)
#         ;
#
#
#
#
#             var circle_62e71ad8b1c96de6ca946d44d77ab486 = L.circle(
#                 [51.4893335, -0.1440550845276872],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;

# %% [markdown]
# These maps can also be viewed in a separate window:
#
# * {Download}`1450-1475<map_europe_1450-1475.html>`
# * {Download}`1475-1500<map_europe_1475-1500.html>`
# * {Download}`1500-1525<map_europe_1500-1525.html>`
# * {Download}`1525-1550<map_europe_1525-1550.html>`
# * {Download}`1550-1575<map_europe_1550-1575.html>`
# * {Download}`1575-1600<map_europe_1575-1600.html>`
